# %% [markdown]
# Import brightway2 and load the Ecoinvent database

# %%
import brightway2 as bw
bw.projects.set_current("AI of LCA")
bw.bw2setup()

if 'ecoinvent-3.10.1-cutoff' in bw.databases:
    print('ecoinvent 3.10.1 is already present in the project')
else:
    bw.import_ecoinvent_release(
        version='3.10.1',
        system_model='cutoff', # can be cutoff / apos / consequential / EN15804
        username='ICL',
        password='ICL_2019-20'
    )
    
db=bw.Database('ecoinvent-3.10.1-cutoff')
# Out:
# Biosphere database already present!!! No setup is needed
# ecoinvent 3.10.1 is already present in the project

# %% [markdown]
# Import inventory data per functional unit

# %%
import pandas as pd
import subprocess 
# Optionally you can open the Excel file in Microsoft Excel using AppleScript, if ready you can skip this step and go directly to reading the excel file 
file_path = "/Users/ek2517/Documents/GitHub/ARIA/Data_inputs.xlsx"

applescript = f'''
tell application "Microsoft Excel"
    open POSIX file "{file_path}"
    activate
end tell
'''

subprocess.call(["osascript", "-e", applescript])

input("After editing and saving the Excel file, press Enter to continue...")

data_frame = pd.read_excel(file_path, usecols="A:B", nrows=12)  

# Remove rows with any empty cells
data_frame.dropna(inplace=True)

# Reset the index after dropping rows
data_frame.reset_index(drop=True, inplace=True)

# Display the DataFrame to verify contents
print("Imported data:")
print(data_frame)
# Out:
# After editing and saving the Excel file, press Enter to continue...
# Imported data:
#          Input/output    In/out
# 0    Sodium hydroxide  1.722910
# 1              Copper  0.330025
# 2      Cobalt sulfate  0.953811
# 3  Manganese sulphate  0.929307
# 4      Nickel sulfate  0.952290
# 5            Graphite  0.902995

# %% [markdown]
# Setup the openAI API

# %%
from openai import OpenAI
import openai
#Enter your API key here 
api_key="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"
# Specify the path to your Excel file
client = openai.OpenAI(api_key=api_key)

# %% [markdown]
# Define supporting functions to help us find matches in the Ecoinvent database

# %%
def build_search_query(term):
    """
    Constructs a wildcard search query from a term.
    E.g., "waste graphite" becomes "*waste* *graphite*".
    """
    terms = term.split()
    return "*" + "* *".join(terms) + "*"

def get_alternative_search_terms(search_term):
    """
    Uses the ChatGPT API to suggest alternative search terms.
    
    Given an original search term (e.g., "waste graphite"), this function asks ChatGPT
    to provide a comma-separated list of alternative search terms that could capture similar datasets.
    """
    prompt = (
        f"Suggest a list of 3 alternative search terms that could be used to find similar datasets "
        f"for the activity '{search_term}' in the ecoinvent database. Each suggestion should modify "
        f"the material name to represent similar materials. Return the suggestions as a comma-separated list."
    )
    
    try:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo",  # or use another model if desired
            messages=[
                {"role": "system", "content": "You are a helpful assistant that provides alternative search queries."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.7,
            max_tokens=50
        )
        suggestions_text = response.choices[0].message.content.strip()
        # Split the response into a list of suggestions using commas as the separator.
        suggestions = [s.strip() for s in suggestions_text.split(',')]
        return suggestions
    except Exception as e:
        print("Error calling ChatGPT API:", e)
        return []

# %% [markdown]
# Try to find matches for each flow included in the imported data

# %%
# --- Main Processing Loop over the DataFrame ---
for index, row in data_frame.iterrows():
    # Get the full sentence (activity name) from the current row
    activity_name = row["Input/output"].strip().lower()  # Ensure it's lowercase and stripped of whitespace
    print(f"\nProcessing row {index + 1}: {activity_name}")
    
    # Define locations to filter
    locations = ["GLO", "RoW", "GB"]
    search_results = []

    # --- Step 1: Initial Search ---
    initial_query = build_search_query(activity_name)
    for location in locations:
        # Execute the search using the generated query string.
        search_results.extend(
            db.search(initial_query, limit=50, filter={"location": location})
        )

    # Check if any results were found
    if search_results:
        print(f"Found {len(search_results)} matching activities for '{activity_name}':")
        results_string = ""
        for result in search_results:
            results_string += f"- {result['name']}, {result['location']}\n"
        print(results_string)
    else:
        print(f"No matching activities found for '{activity_name}'.")
        
        # --- Step 2: Use ChatGPT to Suggest Alternative Search Terms ---
        alternative_terms = get_alternative_search_terms(activity_name)
        if alternative_terms:
            print("ChatGPT suggested the following alternative search terms:", alternative_terms)
            found_alternative = False
            # Try each alternative suggestion until matching datasets are found.
            for alt_term in alternative_terms:
                revised_query = build_search_query(alt_term)
                alternative_results = []
                for location in locations:
                    alternative_results.extend(
                        db.search(revised_query, limit=50, filter={"location": location})
                    )
                if alternative_results:
                    print(f"\nFound {len(alternative_results)} matching activities for alternative search term '{alt_term}':")
                    results_string = ""
                    for result in alternative_results:
                        results_string += f"- {result['name']}, {result['location']}\n"
                    print(results_string)
                    found_alternative = True
                    break  # Stop after the first successful alternative is found.
            if not found_alternative:
                print("No matching datasets found even after trying ChatGPT suggested alternative search terms.")
        else:
            print("No alternative search term suggestions were received from ChatGPT.")

        
    chat_completion = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": (
                    #
                    f"I am performing a life cycle assessment of a battery recycling process to recover valuable materials from electric vehicle batteries\n"
                    f"The product system utilises lithium carbonate to relithiate the recovered cathode material, resulting in regenerated cathode material and waste flows, resulting from non-cathode materials included in lithium-ion batteries\n"
                    f". The geographical scope of the study is in the UK, therefore datasets that include GB should be given prference, if you can't find matches use RoW or GLO, else choose a country closest to the UK. In this you should account for the different country codes included in the ecoinvent database .\n"
                )
            },
            
            {"role": "user", "content": (
                    f"The Ecoinvent database found the following results'{results_string}' related to'{activity_name}' \n"
                    f"Choose one dataset to be used for '{activity_name}' for life cycle assessment under the following rules:\n"
                    f"1. If they exists, you should give the highest preference to datasets that include the exact term '{activity_name}'.\n"
                    f"2.You must only print the exact name of the recommended dataset in the original format as shown in' {results_string}' without any extra text, special characters, explanation, or punctuation."
                    f"3.You should always give preference to datasets that include the exact terms as appearing in term '{activity_name}'.\n"
                    f"4. If '{activity_name}' includes the term production, never choose a dataset that includes the term waste"
                    f"4. If '{activity_name}' includes the term waste, never choose a dataset that includes the term production, you can give preference to the ones including the word treatment"
                )
            }
        ]
    )
    # Extract the response from ChatGPT
    response_content = chat_completion.choices[0].message.content.strip()
    print("ChatGPT Response:")
    print(response_content)

    # Save the ChatGPT response in the new column for the current row
    data_frame.at[index, "Ecoinvent process"] = response_content

print(data_frame.to_string(index=False))
# Out:
# Processing row 1: sodium hydroxide
# Excluding 146 filtered results
# Excluding 135 filtered results
# Excluding 190 filtered results
# Found 94 matching activities for 'sodium hydroxide':
# - disodium disulphite production, GLO
# - trisodium phosphate production, GLO
# - sodium fluoride production, GLO
# - sodium formate production, GLO
# - sodium persulfate production, GLO
# - sodium methoxide production, GLO
# - sodium tetrafluoroborate production, GLO
# - sodium aluminate production, powder, GLO
# - sodium hydrogen sulfate production, GLO
# - chlor-alkali electrolysis, diaphragm cell, GLO
# - chlor-alkali electrolysis, mercury cell, GLO
# - soda ash, dense, to generic market for neutralising agent, GLO
# - chlor-alkali electrolysis, diaphragm cell, GLO
# - chlor-alkali electrolysis, diaphragm cell, GLO
# - chlor-alkali electrolysis, mercury cell, GLO
# - chlor-alkali electrolysis, mercury cell, GLO
# - aluminium collector foil production, for Li-ion battery, GLO
# - diethyl ether production, GLO
# - diethyl ether production, GLO
# - phosphane production, GLO
# - polyphenylene sulfide production, GLO
# - methallylchloride production, GLO
# - tebuconazole production, GLO
# - cryolite production, from fluosilicic acid, GLO
# - cryolite production, from fluosilicic acid, GLO
# - chloridazon production, GLO
# - prochloraz production, GLO
# - triclopyr production, GLO
# - dichlobenil production, GLO
# - ioxynil production, GLO
# - metazachlor production, GLO
# - bromoxynil production, GLO
# - amidosulfuron production, GLO
# - fluazifop-butyl production, GLO
# - mepiquat chloride production, GLO
# - chlorpropham production, GLO
# - prohexadione calcium production, GLO
# - 1-naphthylacetic acid production, GLO
# - paclobutrazol production, GLO
# - triphenyl phosphate production, GLO
# - monochloropentafluoroethane production, chlorofluorination of ethylene, GLO
# - monochloropentafluoroethane production, chlorofluorination of ethylene, GLO
# - tris(2,4-ditert-butylphenyl) phosphite production, GLO
# - alkyl sulphate (C12-14) production, GLO
# - market for sodium oxide, RoW
# - sodium hydroxide to generic market for neutralising agent, RoW
# - market for neutralising agent, sodium hydroxide-equivalent, RoW
# - pentaerythritol production in sodium hydroxide solution, RoW
# - sodium ethoxide production, RoW
# - sodium phenolate production, RoW
# - sodium hydrosulfide production, RoW
# - sodium nitrite production, RoW
# - sodium sulfite production, RoW
# - sodium nitrate production, RoW
# - sodium cyanide production, RoW
# - sodium ethyl xanthate production, RoW
# - sodium hydrogen sulfite production, RoW
# - sodium dithionite production, anhydrous, RoW
# - sodium cumenesulphonate production, RoW
# - market for sodium hydroxide, without water, in 50% solution state, RoW
# - sodium silicate production, spray powder, 80%, RoW
# - sodium bicarbonate, to generic market for neutralising agent, RoW
# - pentaerythritol production in sodium hydroxide solution, RoW
# - NMC811 hydroxide production, for Li-ion battery, RoW
# - NMC111 hydroxide production, for Li-ion battery, RoW
# - NCA hydroxide production, for Li-ion battery, RoW
# - chlor-alkali electrolysis, membrane cell, RoW
# - NMC811 hydroxide production, for Li-ion battery, RoW
# - NMC111 hydroxide production, for Li-ion battery, RoW
# - chlor-alkali electrolysis, membrane cell, RoW
# - NCA hydroxide production, for Li-ion battery, RoW
# - lithium carbonate production, from spodumene, RoW
# - fosetyl-Al production, RoW
# - aluminium hydroxide production, RoW
# - chlor-alkali electrolysis, membrane cell, RoW
# - soda ash, light, crystalline, heptahydrate, to generic market for neutralising agent, RoW
# - chlor-alkali electrolysis, membrane cell, RoW
# - chlor-alkali electrolysis, membrane cell, RoW
# - chlor-alkali electrolysis, membrane cell, RoW
# - chlor-alkali electrolysis, membrane cell, RoW
# - cobalt sulfate production, RoW
# - zirconium oxide production, RoW
# - bleaching, textile, RoW
# - market for deinking emulsion, in paper production, RoW
# - glycerine production, from epichlorohydrin, RoW
# - lithium carbonate production, from spodumene, RoW
# - rosin size production, for paper production, RoW
# - polycarbonate production, RoW
# - ethylene diamine production, from ethylene dichloride, RoW
# - cryolite production, RoW
# - hexamethylene-1,6-diisocyanate production, RoW
# - alkylbenzene sulfonate production, linear, petrochemical, RoW
# - isophorondiisocyanate production, RoW
# - fatty alcohol sulfate production, palm oil, RoW
#
# ChatGPT Response:
# - sodium hydroxide to generic market for neutralising agent, RoW
#
# Processing row 2: copper
# Excluding 931 filtered results
# Excluding 1208 filtered results
# Excluding 1454 filtered results
# Found 104 matching activities for 'copper':
# - treatment of copper cake, GLO
# - electrorefining of copper, anode, GLO
# - market for copper carbonate, GLO
# - market for copper sulfate, GLO
# - market for copper slag, GLO
# - market for electrolyte, copper-rich, GLO
# - copper, anode to generic market for copper-rich materials, GLO
# - electrorefining of copper, anode, GLO
# - market for copper oxide, GLO
# - market for copper, anode, GLO
# - market for copper, cathode, GLO
# - market for copper cake, GLO
# - electrolyte, copper-rich to generic market for copper-rich materials, GLO
# - processing of anode slime from electrorefining of copper, anode, GLO
# - market for copper smelting facility, GLO
# - copper production, cathode, solvent extraction and electrowinning process, GLO
# - market for copper telluride cement, GLO
# - market for sheet rolling, copper, GLO
# - market for wire drawing, copper, GLO
# - treatment of leach residue from copper production, neutralisation, GLO
# - treatment of copper in car shredder residue, municipal incineration, GLO
# - market for copper-rich materials, GLO
# - treatment of copper slag, residual material landfill, GLO
# - market for metal working, average for copper product manufacturing, GLO
# - market for copper concentrate, sulfide ore, GLO
# - market for leach residue from copper production, GLO
# - market for copper scrap, sorted, pressed, GLO
# - market for stockpiling of anode slime from electrorefining of copper, anode, GLO
# - copper collector foil production, for Li-ion battery, GLO
# - market for residues, MSWI, copper in car shredder residue, GLO
# - market for anode slime from electrorefining of copper, anode, GLO
# - treatment of residues, MSWI, copper in car shredder residue, residual material landfill, GLO
# - market for mine infrastructure, gold-silver-zinc-lead-copper, GLO
# - market for bottom ash, MSWI, copper in car shredder residue, GLO
# - market for copper collector foil, for Li-ion battery, GLO
# - market for process-specific burdens, import of copper to Switzerland, GLO
# - market for selective coat, copper sheet, sputter deposition, GLO
# - market for selective coat, copper sheet, black chrome, GLO
# - market for selective coat, copper sheet, black majic, GLO
# - market for metal part of electronics scrap, in copper, anode, GLO
# - treatment of bottom ash, MSWI, copper in car shredder residue, slag compartment, GLO
# - copper sulfate production, GLO
# - market for selective coat, copper sheet, physical vapour deposition, GLO
# - treatment of non-Fe-Co-metals, from used Li-ion battery, hydrometallurgical processing, GLO
# - treatment of used cable, GLO
# - processing of anode slime from electrorefining of copper, anode, GLO
# - processing of anode slime from electrorefining of copper, anode, GLO
# - processing of anode slime from electrorefining of copper, anode, GLO
# - molybdenite mine operation, GLO
# - copper production, cathode, solvent extraction and electrowinning process, GLO
# - copper oxide production, RoW
# - treatment of copper scrap by electrolytic refining, RoW
# - market for scrap copper, RoW
# - smelting of copper concentrate, sulfide ore, RoW
# - treatment of scrap copper, municipal incineration, RoW
# - copper carbonate production, RoW
# - copper mine operation and beneficiation, sulfide ore, RoW
# - treatment of metal part of electronics scrap, in copper, anode, by electrolytic refining, RoW
# - market for copper in car shredder residue, RoW
# - sheet rolling, copper, RoW
# - market for sulfidic tailings, from copper mine operation, RoW
# - market for bottom ash, MSWI, scrap copper, RoW
# - treatment of bottom ash, MSWI, scrap copper, slag compartment, RoW
# - selective coating, copper sheet, black chrome, RoW
# - treatment of electronics scrap, metals recovery in copper smelter, RoW
# - treatment of sulfidic tailings, from copper mine operation, tailings impoundment, RoW
# - wire drawing, copper, RoW
# - copper smelting facility construction, RoW
# - smelting of copper concentrate, sulfide ore, RoW
# - copper mine operation and beneficiation, sulfide ore, RoW
# - selective coating, copper sheet, sputtering, RoW
# - treatment of electronics scrap, metals recovery in copper smelter, RoW
# - treatment of metal part of electronics scrap, in copper, anode, by electrolytic refining, RoW
# - treatment of metal part of electronics scrap, in copper, anode, by electrolytic refining, RoW
# - selective coating, copper sheet, black majic, RoW
# - metal working, average for copper product manufacturing, RoW
# - stockpiling of anode slime from electrorefining of copper, anode, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
# - selective coating, copper sheet, physical vapour deposition, RoW
# - mine construction, gold-silver-zinc-lead-copper, RoW
# - primary zinc production from concentrate, RoW
# - 1-propanol production, RoW
# - aluminium alloy production, AlLi, RoW
# - aluminium alloy production, Metallic Matrix Composite, RoW
# - tellurium production, semiconductor-grade, RoW
# - titanium dioxide production, sulfate process, RoW
# - stibnite mine operation and beneficiation, RoW
# - transmission network construction, electricity, high voltage direct current subsea cable, RoW
# - evacuated tube collector production, RoW
# - soft solder production, Sn97Cu3, RoW
# - flat plate solar collector production, Cu absorber, RoW
# - treatment of waste rubber, unspecified, municipal incineration, RoW
# - treatment of waste rubber, unspecified, municipal incineration, RoW
# - treatment of scrap steel, municipal incineration, RoW
# - treatment of waste rubber, unspecified, municipal incineration, RoW
# - treatment of scrap aluminium, municipal incineration, RoW
# - treatment of wood ash mixture, pure, municipal incineration, RoW
# - treatment of waste paint, municipal incineration, RoW
# - evacuated tube collector production, GB
# - treatment of municipal solid waste, municipal incineration, GB
# - treatment of municipal solid waste, municipal incineration, GB
# - treatment of municipal solid waste, municipal incineration, GB
#
# ChatGPT Response:
# - market for copper sulfate, GLO
#
# Processing row 3: cobalt sulfate
# Excluding 36 filtered results
# Excluding 12 filtered results
# Excluding 40 filtered results
# Found 32 matching activities for 'cobalt sulfate':
# - cobalt production, GLO
# - cobalt production, GLO
# - smelting and refining of nickel concentrate, 16% Ni, GLO
# - disodium disulphite production, GLO
# - market for cobalt sulfate, RoW
# - cobalt sulfate production, RoW
# - primary zinc production from concentrate, RoW
# - NMC811 hydroxide production, for Li-ion battery, RoW
# - NMC111 hydroxide production, for Li-ion battery, RoW
# - NCA hydroxide production, for Li-ion battery, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
# - NMC811 hydroxide production, for Li-ion battery, RoW
# - primary zinc production from concentrate, RoW
# - NMC111 hydroxide production, for Li-ion battery, RoW
# - NCA hydroxide production, for Li-ion battery, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
# - primary zinc production from concentrate, RoW
#
# ChatGPT Response:
# - cobalt sulfate production, RoW
#
# Processing row 4: manganese sulphate
# Excluding 9 filtered results
# Excluding 10 filtered results
# Excluding 10 filtered results
# Found 1 matching activities for 'manganese sulphate':
# - market for manganese sulfate, GLO
#
# ChatGPT Response:
# - market for manganese sulfate, GLO
#
# Processing row 5: nickel sulfate
# Excluding 22 filtered results
# Excluding 22 filtered results
# Excluding 28 filtered results
# Found 12 matching activities for 'nickel sulfate':
# - nickel sulfate production, GLO
# - market for nickel sulfate, GLO
# - smelting and refining of nickel concentrate, 16% Ni, GLO
# - cobalt production, GLO
# - cobalt production, GLO
# - lithium hydroxide production, GLO
# - NCA hydroxide production, for Li-ion battery, RoW
# - NMC811 hydroxide production, for Li-ion battery, RoW
# - NMC111 hydroxide production, for Li-ion battery, RoW
# - NCA hydroxide production, for Li-ion battery, RoW
# - NMC811 hydroxide production, for Li-ion battery, RoW
# - NMC111 hydroxide production, for Li-ion battery, RoW
#
# ChatGPT Response:
# - nickel sulfate production, GLO
#
# Processing row 6: graphite
# Excluding 40 filtered results
# Excluding 27 filtered results
# Excluding 46 filtered results
# Found 25 matching activities for 'graphite':
# - market for graphite, GLO
# - market for polystyrene foam slab with graphite, 6% recycled, GLO
# - chlor-alkali electrolysis, mercury cell, GLO
# - chlor-alkali electrolysis, mercury cell, GLO
# - chlor-alkali electrolysis, mercury cell, GLO
# - phosphane production, GLO
# - graphite production, RoW
# - synthetic graphite production, battery grade, RoW
# - market for synthetic graphite, battery grade, RoW
# - anode production, graphite, for Li-ion battery, RoW
# - market for anode, graphite, for Li-ion battery, RoW
# - market for anode, silicon coated graphite, for Li-ion battery, RoW
# - anode production, silicon coated graphite, NMC811, for Li-ion battery, RoW
# - anode production, silicon coated graphite, NCA, for Li-ion battery, RoW
# - battery cell production, Li-ion, LFP, RoW
# - battery production, Li-ion, NMC111, rechargeable, prismatic, RoW
# - battery production, Li-ion, NCA, rechargeable, prismatic, RoW
# - battery production, Li-ion, NMC811, rechargeable, prismatic, RoW
# - battery production, Li-ion, LFP, rechargeable, prismatic, RoW
# - battery cell production, Li-ion, NMC811, RoW
# - battery cell production, Li-ion, NMC111, RoW
# - battery cell production, Li-ion, NCA, RoW
# - magnesium production, electrolysis, RoW
# - cathode production, LFP, for Li-ion battery, RoW
# - magnesium production, electrolysis, RoW
#
# ChatGPT Response:
# - graphite production, RoW
#       Input/output   In/out                                                Ecoinvent process
#   Sodium hydroxide 1.722910 - sodium hydroxide to generic market for neutralising agent, RoW
#             Copper 0.330025                                 - market for copper sulfate, GLO
#     Cobalt sulfate 0.953811                                 - cobalt sulfate production, RoW
# Manganese sulphate 0.929307                              - market for manganese sulfate, GLO
#     Nickel sulfate 0.952290                                 - nickel sulfate production, GLO
#           Graphite 0.902995                                       - graphite production, RoW
